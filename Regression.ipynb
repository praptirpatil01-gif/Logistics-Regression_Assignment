# %% [markdown]
# Q.1: What is Simple Linear Regression (SLR)? Explain its purpose.
#
# Ans:-
# Simple Linear Regression is a statistical method used to study the relationship between one independent variable and one dependent variable. It represents this relationship using a straight line.
#
# The purpose of SLR is to predict the value of the dependent variable and to understand how changes in the independent variable affect it.
# ____
# Q2. What are the key assumptions of Simple Linear Regression?
#
# Ans:-
# The key assumptions are:
#
# 1.   The relationship between variables should be linear.
#  1.   Observations should be independent.
#
# 1.  The variance of errors should remain constant.
# 2.  Errors should be normally distributed.
#
#
# 2.   There should be no extreme outliers affecting the model.
# ___
# Q3. Write the mathematical equation for a simple linear regression model and explain each term.
#
# Ans:-
#
# A simple linear regression model contains:
#
# * Dependent variable (output variable)
#
# * Independent variable (input variable)
#
# * Slope (shows how much the output changes when input changes)
#
# * Intercept (value of output when input is zero)
#
# The slope represents the rate of change, and the intercept represents the starting value.
# ____
# Q4. Provide a real-world example where simple linear regression can be applied.
#
# Ans:-
#
# One real-world example is predicting a student’s marks based on the number of hours studied.
#
# Here, study hours are the independent variable and marks are the dependent variable. The model helps estimate marks based on study time.
# ____
# Q5. What is the method of least squares in linear regression?
#
# Ans:-
#
# The method of least squares is a technique used to find the best-fitting line for the data.
#
# It works by minimizing the total difference between the actual values and the predicted values. This ensures the model makes the smallest possible prediction error.
# ____
# Q6. What is Logistic Regression? How does it differ from Linear Regression?
#
# Ans:-
#
# Logistic Regression is a supervised learning algorithm used for classification problems, such as predicting yes/no or true/false outcomes.
#
# Linear Regression:-
#
# * Used for predicting continuous numerical values.
#
# * Output can be any real number.
#
# Logistic Regression:-
#
# * Used for classification problems.
#
# * Output represents probability between 0 and 1.
# ___
# Q7. Name and briefly describe three common evaluation metrics for regression models.
#
# Ans:-
#
# * Mean Absolute Error (MAE):
#  Measures the average absolute difference between actual and predicted values.
#
# * Mean Squared Error (MSE):
# Measures the average of squared prediction errors and penalizes large errors more.
#
# * Root Mean Squared Error (RMSE):
# Square root of MSE; gives error in the same unit as the target variable.
# ____
# Q8. What is the purpose of the R-squared metric in regression analysis?
#
# Ans:-
#
# * R-squared measures how well the regression model explains the variation in the dependent variable.
#
# * A higher R-squared value means the model explains more of the data and fits better.
# ____
# Q9. Write Python code to fit a simple linear regression model using scikit-learn and print the slope and intercept.
#
# Ans:-

# %%
import numpy as np
from sklearn.linear_model import LinearRegression

X = np.array([[1], [2], [3], [4], [5]])
Y = np.array([2, 4, 6, 8, 10])

model = LinearRegression()
model.fit(X, Y)

print("Slope:", model.coef_[0])
print("Intercept:", model.intercept_)
# Out:
# Slope: 2.0
# Intercept: 0.0

# %% [markdown]
# Q10. How do you interpret the coefficients in a simple linear regression model?
#
# Ans:-
#
# The slope tells us how much the dependent variable changes when the independent variable increases by one unit.
#
# If the slope is positive, the relationship is positive. If it is negative, the relationship is negative.
#
# The intercept represents the value of the dependent variable when the independent variable is zero.
# ____
# ____
# **End**
